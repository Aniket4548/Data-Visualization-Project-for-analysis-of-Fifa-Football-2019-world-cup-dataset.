# %% [markdown]
# # Practical 4

# %% [markdown]
# # Data Visualization Project for analysis of Fifa Football 2019 world cup dataset.

# %%
import pandas as pd  #importing pandas library
import numpy as np  #importing numpy library

# %%
import matplotlib.pyplot as plt  #importing pyplot module from matplotlib library

# %%
df = pd.read_csv("D:/Machine Learning/FIFA dataset/fifa_eda.csv")
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
df.shape  #checking the shape of dataset
# Out:
# (18207, 18)

# %%
#Histogram

# %%
plt.hist(df['Overall']) #histogram are approximations to distributions generated through value based on a set
# x axis = range, y axis = frequency
# Out:
# (array([ 192.,  998., 2363., 4727., 4289., 3570., 1513.,  445.,   96.,
#           14.]),
#  array([46. , 50.8, 55.6, 60.4, 65.2, 70. , 74.8, 79.6, 84.4, 89.2, 94. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Overall'], edgecolor = 'black' , bins = 15)  #create histogram and specifying bin size and border color
plt.xlabel ('Overall')  #giving label to x axis
plt.ylabel ('Frequency')  #giving label to y axis
plt.title ('Histogram of Overall Player Ratings in FIFA19')  #giving histogram title
plt.show()  #display graph

# %%
width = 5
plt.hist(df['Overall'], edgecolor = 'black' , bins = np.arange(min(df['Overall']),max(df['Overall']) + width ,width))
#create histogram and specifying bin size and border color
plt.xlabel ('Overall')  #giving label to x axis
plt.ylabel ('Frequency')  #giving label to y axis
plt.title ('Histogram of Overall Player Ratings in FIFA 19')  #giving histogram title
plt.show()  #display graph

# %%
#no.of bins = [log2n + 1]
#optimal no. of bins = [log2n + 1] = log2 [(18207)+1] = 15 approx
plt.hist(df['Overall'], edgecolor = 'White' , facecolor = 'red' , bins = 15 , range = [50,90])
plt.xlabel ('Overall')  #giving label to x axis
plt.ylabel ('Frequency')  #giving label to y axis
plt.title ('Histogram of Overall Player Ratings in FIFA 19')  #giving histogram title
plt.show()  #display graph

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                       float64
# Wage                        float64
# Preferred Foot               object
# International Reputation    float64
# Skill Moves                 float64
# Position                     object
# Joined                        int64
# Contract Valid Until         object
# Height                      float64
# Weight                      float64
# Release Clause              float64
# dtype: object

# %%
#Scatter plot
#useful for data visualisation tool that helps us with indentifying variable dependencies

# %%
plt.scatter(df['Overall'], df['Wage'])
plt.title('Overall vs Wage')
plt.ylabel('Wage')
plt.xlabel('Overall')
plt.show()

# %%
#Bar chart
#analysing categorical data
from collections import Counter  #helps in counting the value of each value
print(Counter(df['Nationality']))
#you will get a dictionary as an output
# Out:
# Counter({'England': 1662, 'Germany': 1198, 'Spain': 1072, 'Argentina': 937, 'France': 914, 'Brazil': 827, 'Italy': 702, 'Colombia': 618, 'Japan': 478, 'Netherlands': 453, 'Sweden': 397, 'China PR': 392, 'Chile': 391, 'Republic of Ireland': 368, 'Mexico': 366, 'United States': 353, 'Poland': 350, 'Norway': 341, 'Saudi Arabia': 340, 'Denmark': 336, 'Korea Republic': 335, 'Portugal': 322, 'Turkey': 303, 'Austria': 298, 'Scotland': 286, 'Belgium': 260, 'Australia': 236, 'Switzerland': 220, 'Uruguay': 149, 'Senegal': 130, 'Wales': 129, 'Croatia': 126, 'Serbia': 126, 'Nigeria': 121, 'Ghana': 114, 'Greece': 102, 'Czech Republic': 100, 'Ivory Coast': 100, 'Cameroon': 90, 'Morocco': 85, 'Paraguay': 85, 'Northern Ireland': 80, 'Russia': 79, 'Ukraine': 73, 'South Africa': 71, 'Finland': 67, 'Venezuela': 67, 'Canada': 64, 'Bosnia Herzegovina': 61, 'Algeria': 60, 'Slovenia': 55, 'Slovakia': 54, 'Romania': 54, 'DR Congo': 52, 'Iceland': 47, 'New Zealand': 44, 'Ecuador': 43, 'Mali': 43, 'Albania': 
# ...

# %%
#Filter out the most common nationality values
print (dict(Counter(df['Nationality']).most_common(15)))
# Out:
# {'England': 1662, 'Germany': 1198, 'Spain': 1072, 'Argentina': 937, 'France': 914, 'Brazil': 827, 'Italy': 702, 'Colombia': 618, 'Japan': 478, 'Netherlands': 453, 'Sweden': 397, 'China PR': 392, 'Chile': 391, 'Republic of Ireland': 368, 'Mexico': 366}

# %%
#To filter out most uncommon nationaality values
least_common = Counter(df['Nationality']).most_common()[::-1]
print(least_common[0:10])
# Out:
# [('Botswana', 1), ('Indonesia', 1), ('South Sudan', 1), ('Belize', 1), ('Malta', 1), ('Andorra', 1), ('Qatar', 1), ('Rwanda', 1), ('Jordan', 1), ('Grenada', 1)]

# %%
print(least_common[0:30])
# Out:
# [('Botswana', 1), ('Indonesia', 1), ('South Sudan', 1), ('Belize', 1), ('Malta', 1), ('Andorra', 1), ('Qatar', 1), ('Rwanda', 1), ('Jordan', 1), ('Grenada', 1), ('Puerto Rico', 1), ('Ethiopia', 1), ('St Lucia', 1), ('Palestine', 1), ('Lebanon', 1), ('Guam', 1), ('Liberia', 1), ('Mauritius', 1), ('Kuwait', 1), ('New Caledonia', 1), ('Fiji', 1), ('Oman', 1), ('São Tomé & Príncipe', 1), ('United Arab Emirates', 1), ('Hong Kong', 2), ('Nicaragua', 2), ('Bermuda', 2), ('Eritrea', 2), ('Philippines', 2), ('Chad', 2)]

# %%
nationality_dict = dict(Counter(df['Nationality']).most_common(10))
plt.bar(nationality_dict.keys(),nationality_dict.values())
plt.xlabel('Nationality')
plt.ylabel('Frequency')
plt.title('Bar Plot of Ten Most CommonCountries')
# Out:
# Text(0.5, 1.0, 'Bar Plot of Ten Most CommonCountries')

# %%
nationality_dict = dict(Counter(df['Nationality']).most_common(10))
plt.bar(nationality_dict.keys(),nationality_dict.values())
plt.xlabel('Nationality')
plt.ylabel('Frequency')
plt.title('Bar Plot of Ten Most Common Nationality')
plt.xticks(rotation=90)  #rotates the x axis label by 90 degree
plt.show()

# %%
least_common = Counter(df['Nationality']).most_common()[::-1]
least_common = dict(least_common[:30])
plt.bar(least_common.keys(), least_common.values())
plt.xlabel('Nationality')
plt.ylabel('Frequency')
plt.title('Bar Plot of Ten Least Common Nationality')
plt.xticks(rotation=90)  #rotates the x axis label by 90 degree
plt.show()

# %%
#Pie Chart
#visualize proportion in your data 
df.loc[df.Nationality == 'England', 'Nationality_2'] = 'England'
df.loc[df.Nationality == 'Germany', 'Nationality_2'] = 'Germany'
df.loc[df.Nationality == 'Spain', 'Nationality_2'] = 'Spain'
df.loc[df.Nationality == 'Argentina', 'Nationality_2'] = 'Argentina'
df.loc[df.Nationality == 'Brazil', 'Nationality_2'] = 'Brazil'
df.loc[df.Nationality == 'Italy', 'Nationality_2'] = 'Italy'
df.loc[~ df.Nationality.isin(['England','Germany','Spain','Argentina','Brazil','Italy']) , 'Nationality_2'] = 'Other'
#create a dictionary that contains the proportion value of these:
proportion = dict(Counter(df['Nationality_2']))
for key, values in proportion.items() : 
    proportion[key] = (values)/len(df)*100
print(proportion)
# Out:
# {'Argentina': 5.146372274399956, 'Other': 64.85966935793925, 'Brazil': 4.542209040478936, 'Spain': 5.887845334212116, 'Germany': 6.579886856703466, 'England': 9.12835722524304, 'Italy': 3.8556599110232326}

# %%
plt.pie(proportion.values(),labels = proportion.keys(), autopct = '%1.2f%%')
plt.figure(figsize = (20,15))
plt.show()

# %%
explode = (0,0,0,0,0,0.3,0)
plt.pie(proportion.values(),labels = proportion.keys(), autopct = '%1.2f%%' , explode=explode)
plt.figure(figsize = (20,15))
plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(df['Overall'])  #dist plot shows the distribution and shows us the nature of the plot wether the distribution is normal right skewed or right skewed
plt.xlabel('Overall')
plt.ylabel('Frequency')
plt.title('Histogram of Overall Rating')
plt.grid()
plt.show()
# Out:
# C:\Users\ANIKET KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(df['Overall'], df['Wage'])
plt.xlabel('Overall')
plt.ylabel('Frequency')
plt.title('Overall vs Wage')
plt.grid()
plt.show()
# Out:
# C:\Users\ANIKET KUMAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#heatmap
corr = df[['Overall','Age','Wage','Skill Moves','Potential']].corr()
sns.heatmap(corr, annot= True)  #we set annot for annotate to true to see the corellation values
plt.title('Heatmap of Overall ,Age, Wage_Euro and Skill Moves')
plt.show()

# %%
#pair plots
#allows to generate matrix of distribution of scatterplot for set of numeric features
data = df[['Overall','Age','Potential','Wage', ]]
sns.pairplot(data)
plt.grid()
plt.show()
